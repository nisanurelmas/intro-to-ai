# %%
    import matplotlib.pyplot as plt

# İlk veri seti
x1 = [1, 2, 3, 4, 5]


# İkinci veri seti
x2 = [10, 20, 30, 40, 50]

length = range(len(x2))

# İlk veri setini scatter grafiğine ekleme (mavi)
plt.scatter(x1,length,  label='Veri Seti 1') # renk vermezsen kendi koyuyor farkı

# İkinci veri setini scatter grafiğine ekleme (kırmızı)
plt.scatter(x2, length, label='Veri Seti 2')

# Grafiği gösterme
plt.xlabel("X Ekseni")
plt.ylabel("Y Ekseni")
plt.title("Birden Fazla Veri Seti ile Scatter Grafiği")
plt.legend()
plt.show()

# %%
import tensorflow as tf
import tensorflow.keras
# from tensorflow.keras import layers, models böyle yap sarıları
import numpy as np
import matplotlib.pyplot as plt

# MNIST veri setini yükleyin
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Veriyi normalleştirin (0-255 aralığındaki değerleri 0-1 aralığına getirin)
x_train, x_test = x_train / 255.0, x_test / 255.0

# Modeli oluşturun
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Girdi katmanı (28x28 görüntüyü düzleştirin)
    layers.Dense(128, activation='relu'),  # Gizli katman (128 nöronlu, ReLU aktivasyonlu)
    layers.Dense(10, activation='softmax')  # Çıktı katmanı (10 sınıf için softmax aktivasyonlu)
])

# Modeli derleyin
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Modeli eğitin
history = model.fit(x_train, y_train, epochs=1, validation_split=0.2)

# Modeli değerlendirin
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f'Test accuracy: {test_acc}')

# Eğitim geçmişini görselleştirin
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()
# Out:
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.2878 - accuracy: 0.9186 - val_loss: 0.1556 - val_accuracy: 0.9544
# 313/313 - 1s - loss: 0.1479 - accuracy: 0.9551 - 1s/epoch - 3ms/step
# Test accuracy: 0.9550999999046326

# %%
# Gerekli kütüphaneleri yükleyin
import numpy as np
import matplotlib.pyplot as plt
import sklearn.model_selection
import sklearn.linear_model
import sklearn.metrics



# Örnek veri seti oluşturun
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Eğitim ve test setlerine ayırın
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Linear Regression modelini oluşturun
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)

# Tahminlerde bulunun
y_pred_train = lin_reg.predict(X_train)
y_pred_test = lin_reg.predict(X_test)

# Model performansını değerlendirin
print("Eğitim seti MSE:", mean_squared_error(y_train, y_pred_train))
print("Test seti MSE:", mean_squared_error(y_test, y_pred_test))
print("Test seti R2 skoru:", r2_score(y_test, y_pred_test))

# Sonuçları görselleştirin
plt.scatter(X, y, color='blue')
plt.plot(X, lin_reg.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.show()
# Out:
# Eğitim seti MSE: 0.9862320999534522
# Test seti MSE: 1.0434333815695171
# Test seti R2 skoru: 0.7424452332071367
